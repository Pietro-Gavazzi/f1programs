# %%
# quadratic splines

import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline


# Define data points (knots)
x = np.array([0, 1, 2, 3, 4])
y = np.array([1, 2, 1, 3, 2])

# Create a quadratic spline interpolation function
quadratic_spline = interp1d(x, y, kind='quadratic')

# Generate points for plotting the spline
x_interp_quad = np.linspace(0, 4, 100)
y_interp_quad = quadratic_spline(x_interp_quad)


# cubic splines
# Fit a cubic spline to the data points
cs = CubicSpline(x, y)

# Evaluate the spline at finer resolution
x_interp_cub = np.linspace(0, 4, 100)
y_interp_cub = cs(x_interp_cub)

# %%
# Plot the original data and the interpolated spline
plt.figure(figsize=(8, 6))
plt.scatter(x, y, label='Original Data')
plt.plot(x_interp_cub, y_interp_cub, label='Cubic Spline', color='red')
plt.plot(x_interp_quad, y_interp_quad, label='Quadratic Spline', color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Cubic-Square Spline Interpolation')
plt.legend()
plt.grid(True)
plt.show()
